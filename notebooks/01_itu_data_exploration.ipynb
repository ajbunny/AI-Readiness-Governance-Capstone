# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## Download the ITU dataset
df = pd.read_csv("../data/raw/itu_all_indicators_raw_sample.csv")

# %%
df.shape
# Out:
# (376, 15)

# %%
df.head()
# Out:
#    SeriesID                    SeriesCode  \
# 0      9232  HHU4212-%_POP-ISCED01-FEMALE
# 1      8810        HHA4213-%_HH-CHILDREN-
# 2      8816      HHA4213-%_HH-NOCHILDREN-
# 3      9231        HHU4212-%_POP-ISCED01-
# 4      8812   HHA4213-%_HH-CHILDREN-URBAN
#
#                                               Series              Unit  \
# 0  HH07 - Individuals who used the internet (from...  % of individuals
# 1  HH06 - Households with Internet access at home...   % of households
# 2  HH06 - Households with Internet access at home...   % of households
# 3  HH07 - Individuals who used the internet (from...  % of individuals
# 4  HH06 - Households with Internet access at home...   % of households
#
#                   Database  Year AreaName AreaCode DisaggregationGroup  \
# 0  ITU Households Database  2025   France      FRA              Gender
# 1  ITU Households Database  2025   France      FRA              Family
# 2  ITU Households Database  2025   France      FRA              Family
# 3  ITU Households Database  2025   France      FRA           Education
# 4  ITU Households Database  2025   France      FRA            Location
#
#    Disaggregation1 Disaggregation2      Value              Notes  \
# 0  Primary or less          Female  46.944591  Aged 15 and older
# 1         Children             NaN  98.326201                NaN
# 2      No Children             NaN  87.217188                NaN
# 3  Primary or less             NaN  51.695790  Aged 15 and older
# 4         Children           Urban  97.960964                NaN
#
#                                               Source LastModifiedOn
# 0  Institut National de la Statistique et des Etu...     2026-06-26
# 1  Institut National de la Statistique et des Etu...     2026-07-05
# 2  Institut National de la Statistique et des Etu...     2026-07-05
# 3  Institut National de la Statistique et des Etu...     2026-06-02
# 4  Institut National de la Statistique et des Etu...     2026-07-04

# %%
df.tail()
# Out:
#      SeriesID           SeriesCode  \
# 371      8820  HHA4213-%_HH-URBAN-
# 372      8819  HHA4213-%_HH-RURAL-
# 373     12047             xHH6_IDI
# 374     12047             xHH6_IDI
# 375     12047             xHH6_IDI
#
#                                                 Series             Unit  \
# 371  HH06 - Households with Internet access at home...  % of households
# 372  HH06 - Households with Internet access at home...  % of households
# 373  Estimated proportion of households with Intern...  % of households
# 374  Estimated proportion of households with Intern...  % of households
# 375  Estimated proportion of households with Intern...  % of households
#
#                                             Database  Year       AreaName  \
# 371                          ITU Households Database  2018       Portugal
# 372                          ITU Households Database  2018       Portugal
# 373  ITU World Telecommunication Indicators Database  2018      Singapore
# 374  ITU World Telecommunication Indicators Database  2018       Tanzania
# 375  ITU World Telecommunication Indicators Database  2018  United States
#
#     AreaCode DisaggregationGroup Disaggregation1 Disaggregation2      Value  \
# 371      PRT            Location           Urban             NaN  84.787920
# 372      PRT            Location           Rural             NaN  69.103214
# 373      SGP                 NaN             NaN             NaN  97.733872
# 374      TZA                 NaN             NaN             NaN   9.112273
# 375      USA                 NaN             NaN             NaN  85.349794
#
#                                                  Notes  \
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375  Households with Internet subscription. Does no...
#
#                                     Source LastModifiedOn
# 371                    Statistics Portugal     2026-07-05
# 372                    Statistics Portugal     2024-07-08
# 373  Infocomm Media Development Authority      2024-01-23
# 374                           ITU estimate     2021-11-29
# 375                       US Census Bureau     2024-01-23

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SeriesID             376 non-null    int64
#  1   SeriesCode           376 non-null    object
#  2   Series               376 non-null    object
#  3   Unit                 376 non-null    object
#  4   Database             376 non-null    object
#  5   Year                 376 non-null    int64
#  6   AreaName             376 non-null    object
#  7   AreaCode             376 non-null    object
#  8   DisaggregationGroup  324 non-null    object
#  9   Disaggregation1      324 non-null    object
#  10  Disaggregation2      188 non-null    object
#  11  Value                376 non-null    float64
#  12  Notes                47 non-null     object
#  13  Source               376 non-null    object
#  14  LastModifiedOn       376 non-null    object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 44.2+ KB

# %%
df.columns.tolist()
# Out:
# ['SeriesID',
#  'SeriesCode',
#  'Series',
#  'Unit',
#  'Database',
#  'Year',
#  'AreaName',
#  'AreaCode',
#  'DisaggregationGroup',
#  'Disaggregation1',
#  'Disaggregation2',
#  'Value',
#  'Notes',
#  'Source',
#  'LastModifiedOn']

# %%
df["Series"].value_counts()
# Out:
# Series
# Estimated proportion of households with Internet access at home                            52
# HH06 - Households with Internet access at home - %_HH - CHILDREN                           20
# HH06 - Households with Internet access at home - %_HH - NOCHILDREN                         20
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED01 - FEMALE    16
# HH06 - Households with Internet access at home - %_HH - RURAL                              16
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED56 - MALE      16
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED34 - MALE      16
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED01 - MALE      16
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED56 - FEMALE    16
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED34 - FEMALE    16
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED56             16
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED2 - FEMALE     16
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED2              16
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED2 - MALE       16
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED34             16
# HH07 - Individuals who used the internet (from any location) - %_POP - ISCED01             16
# HH06 - Households with Internet access at home - %_HH - URBAN                              16
# HH06 - Households with Internet access at home - %_HH - NOCHILDREN - RURAL                 15
# HH06 - Households with Internet access at home - %_HH - NOCHILDREN - URBAN                 15
# HH06 - Households with Internet access at home - %_HH - CHILDREN - RURAL                   15
# HH06 - Households with Internet access at home - %_HH - CHILDREN - URBAN                   15
# Name: count, dtype: int64

# %%
df["Year"].value_counts()
# Out:
# Year
# 2021    60
# 2023    51
# 2024    49
# 2022    49
# 2018    48
# 2019    47
# 2025    45
# 2020    27
# Name: count, dtype: int64

# %%
df["AreaName"].value_counts()
# Out:
# AreaName
# Portugal         168
# France           148
# Singapore         30
# United States      9
# Ghana              7
# Nigeria            7
# Tanzania           6
# Haiti              1
# Name: count, dtype: int64

# %%
df.groupby(["AreaName", "Year"]).size()
# Out:
# AreaName       Year
# France         2018    21
#                2019    21
#                2020     1
#                2021    21
#                2022    21
#                2023    21
#                2024    21
#                2025    21
# Ghana          2018     1
#                2019     1
#                2020     1
#                2021     1
#                2022     1
#                2023     1
#                2024     1
# Haiti          2018     1
# Nigeria        2018     1
#                2019     1
#                2020     1
#                2021     1
#                2022     1
#                2023     1
#                2024     1
# Portugal       2018    21
#                2019    21
#                2020    21
#                2021    21
#                2022    21
#                2023    21
#                2024    21
#                2025    21
# Singapore      2018     1
#                2019     1
#                2020     1
#                2021    15
#                2022     3
#                2023     3
#                2024     3
#                2025     3
# Tanzania       2018     1
#                2019     1
#                2020     1
#                2022     1
#                2023     1
#                2024     1
# United States  2018     1
#                2019     1
#                2020     1
#                2021     1
#                2022     1
#                2023     3
#                2024     1
# dtype: int64

# %%
country_year_counts = (df.groupby(["AreaName", "Year"]).size().unstack(fill_value=0).rename(columns=lambda x: f"Year_{x}"))

# %%
country_year_counts
# Out:
# Year           Year_2018  Year_2019  Year_2020  Year_2021  Year_2022  \
# AreaName
# France                21         21          1         21         21
# Ghana                  1          1          1          1          1
# Haiti                  1          0          0          0          0
# Nigeria                1          1          1          1          1
# Portugal              21         21         21         21         21
# Singapore              1          1          1         15          3
# Tanzania               1          1          1          0          1
# United States          1          1          1          1          1
#
# Year           Year_2023  Year_2024  Year_2025
# AreaName
# France                21         21         21
# Ghana                  1          1          0
# Haiti                  0          0          0
# Nigeria                1          1          0
# Portugal              21         21         21
# Singapore              3          3          3
# Tanzania               1          1          0
# United States          3          1          0
